# %%
import pandas as pd
import numpy as np
import json
import re
from difflib import SequenceMatcher
from src.ingestion import download_from_drive
from tqdm.notebook import tqdm  # For progress bars

# %%
# Load the databases
df_anagrafica = download_from_drive("csv_startup_anagrafica")
df_crunchbase = download_from_drive("estrazione_crunchbase_5k")

# Display the first few rows of each dataframe to understand their structure
print("Startup Anagrafica Dataset:")
display(df_anagrafica.head())

print("\nCrunchbase Dataset:")
display(df_crunchbase.head())
# Out:
# Startup Anagrafica Dataset:
#    Unnamed: 0                   Ragione sociale  BvD ID number  \
# 0         1.0                   RAINSHOW S.R.L.  IT03595550835
# 1         2.0  CHECKSIG S.R.L. SOCIETA' BENEFIT  IT11028330964
# 2         3.0                   OTOFARMA S.P.A.  IT08431301210
# 3         4.0                SIKELIA OIL S.R.L.  IT03577640836
# 4         5.0                   POWER.IT S.R.L.  IT04355290166
#
#    Codice fiscale Numero CCIAA   Partita IVA         Indirizzo sede legale  \
# 0      3595550835    ME0248323  3.595551e+09       VIA FRANCESCO CRISPI, 4
# 1     11028330964    MI2573724  1.102833e+10            PZA DEL LIBERTY, 8
# 2      8431301210    NA0957454  8.431301e+09     VLE ANTONIO GRAMSCI, 17/B
# 3      3577640836    ME0247028  3.577641e+09  VIA STRETTO I COCCOMELLI, 64
# 4      4355290166    BG0456683  4.355290e+09       VIA ALESSANDRO NOLI, 13
#
#   Provincia  Indirizzo sede legale - Codice postale  \
# 0   Messina                                 98066.0
# 1    Milano                                 20121.0
# 2    Napoli                                 80122.0
# 3   Messina                                 98051.0
# 4   Bergamo                                 24125.0
#
#   Indirizzo sede legale - Regione                   Sede operativa  \
# 0                         Sicilia                              NaN
# 1                       Lombardia             PIAZZA DEL LIBERTY 8
# 2                        Campania  VIA VIC S.M. DEL PIANTO TORRE 2
# 3                         Sicilia                              NaN
# 4                       Lombardia                              NaN
#
#   Sede operativa - Provincia  Sede operativa - Codice postale  \
# 0                        NaN                              NaN
# 1                     Milano                          20121.0
# 2                     Napoli                          80144.0
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   Sede operativa - Regione - Regione  ATECO 2007\ncodice Anno di costituzione  \
# 0                                NaN            711210.0           06/12/2019
# 1                          LOMBARDIA            620100.0           25/10/2019
# 2                           CAMPANIA            266002.0           13/07/2016
# 3                                NaN            473000.0           15/07/2019
# 4                                NaN            352300.0           31/01/2019
#
#    Fondazione Stato giuridico Forma giuridica
# 0         NaN          Attiva          S.R.L.
# 1         NaN          Attiva          S.R.L.
# 2         NaN          Attiva          S.P.A.
# 3         NaN          Attiva          S.R.L.
# 4         NaN          Attiva          S.R.L.
# Crunchbase Dataset:
#          Organization Name                              Organization Name URL  \
# 0                  Enilive    https://www.crunchbase.com/organization/enilive
# 1  Electrolux Professional  https://www.crunchbase.com/organization/electr...
# 2               NanoPhoria  https://www.crunchbase.com/organization/nanoph...
# 3                   Akamas     https://www.crunchbase.com/organization/akamas
# 4        Arsenale Bioyards  https://www.crunchbase.com/organization/arsena...
#
#   IPO Status Company Type                                         Industries  \
# 0    Private   For Profit  Biofuel, Car Sharing, Energy Efficiency, Trans...
# 1     Public   For Profit  Laundry and Dry-cleaning, Machinery Manufacturing
# 2    Private   For Profit              Analytics, Biotechnology, Health Care
# 3    Private   For Profit  Analytics, Application Performance Management,...
# 4    Private   For Profit          Biotechnology, Health Care, Manufacturing
#
#   Number of Employees                    Headquarters Location  \
# 0           1001-5000                       Roma, Lazio, Italy
# 1           1001-5000  Pordenone, Friuli-Venezia Giulia, Italy
# 2                1-10                  Milan, Lombardia, Italy
# 3               11-50                  Milan, Lombardia, Italy
# 4                1-10                  Milan, Lombardia, Italy
#
#   CB Rank (Organization)  Stage CB Rank (Company)  ...   Exit Date  \
# 0                  1,495    NaN             1,173  ...         NaN
# 1                  3,453    NaN             2,808  ...  2020-05-27
# 2                  4,329    NaN             3,530  ...         NaN
# 3                  4,411    NaN             3,623  ...         NaN
# 4                  4,546    NaN             3,719  ...         NaN
#
#   Exit Date Precision  Founded Date Founded Date Precision  Operating Status  \
# 0                 NaN    2023-01-01                   year            Active
# 1                 day    2019-01-01                    day            Active
# 2                 NaN    2022-01-01                   year            Active
# 3                 NaN    2019-01-01                   year            Active
# 4                 NaN    2023-01-01                   year            Active
#
#                                          Description  Estimated Revenue Range  \
# 0  Enilive is Eni's mobility transformation compa...                      NaN
# 1  Electrolux Professional is a global provider o...              $1B to $10B
# 2  NanoPhoria develops non-viral, nano-delivery s...              $1M to $10M
# 3  Akamas AI safely optimizes application workloa...              $1M to $10M
# 4  Arsenale is an innovative end-to-end bio-manuf...                      NaN
#
#   Postal Code                               Headquarters Regions  \
# 0         144  European Union (EU), Europe, Middle East, and ...
# 1         NaN  European Union (EU), Europe, Middle East, and ...
# 2       20122  European Union (EU), Europe, Middle East, and ...
# 3       20158  European Union (EU), Europe, Middle East, and ...
# 4       20122  European Union (EU), Europe, Middle East, and ...
#
#    Number of Portfolio Organizations
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 80 columns]

# %%
import pandas as pd
from thefuzz import process, fuzz

def pulisci_stringa(s: str) -> str:
    """
    Esegue operazioni di cleaning basilari su una stringa:
    - conversione a minuscolo
    - rimozione spazi iniziali/finali
    - (eventualmente) rimozione di punteggiatura o caratteri speciali
    """
    if not isinstance(s, str):
        if s is None:
            return ""
        else:
            return str(s)
    s = s.strip().lower()
    # Remove legal entity types
    s = re.sub(r'\b(srl|s\.r\.l|s\.r\.l\.|s.r.l|spa|s\.p\.a|s\.p\.a\.|s.p.a|inc|llc|ltd|gmbh|corp|corporation)\b', '', s)
    
    # Remove special characters and extra spaces
    s = re.sub(r'[^\w\s]', ' ', s)  # Replace special chars with space
    s = re.sub(r'\s+', ' ', s)       # Replace multiple spaces with single space
    return s

def fuzzy_merge(
    df1: pd.DataFrame,
    df2: pd.DataFrame,
    key1: str,
    key2: str,
    threshold: int = 80
) -> pd.DataFrame:
    """
    Esegue un merge 'fuzzy' tra df1 e df2 in base a key1 (df1) e key2 (df2).
    - threshold definisce il valore minimo di similarità (0-100)
    - Ritorna un DataFrame con le corrispondenze migliori trovate per ogni riga di df1.
    """
    # Copia dei DataFrame per non modificare gli originali
    df1_clean = df1.copy()
    df2_clean = df2.copy()
    
    # Creiamo colonne "pulite" per il matching
    df1_clean['key_clean'] = df1_clean[key1].apply(pulisci_stringa)
    df2_clean['key_clean'] = df2_clean[key2].apply(pulisci_stringa)
    
    # Per facilitare le ricerche, creiamo un dizionario {nome_clean: indice} per df2
    unique_keys2 = df2_clean['key_clean'].unique().tolist()
    
    # Lista per salvare i risultati
    risultati = []

    for idx1, row in df1_clean.iterrows():
        name_to_match = row['key_clean']
        
    # Trova il miglior match in df2 usando thefuzz.process
        # extractOne ritorna (best_match, score, indice)
        best_match, best_score = process.extractOne(name_to_match, unique_keys2, scorer=fuzz.partial_ratio)
        
        if best_score >= threshold:
            # Recuperiamo la riga corrispondente in df2
            match_row = df2_clean[df2_clean['key_clean'] == best_match].iloc[0]
            
            # Costruiamo un dizionario con i dati combinati
            combined_data = {}
            
            # Dati di df1
            for col in df1_clean.columns:
                combined_data[f"df1_{col}"] = row[col]
            
            # Dati di df2
            for col in df2_clean.columns:
                combined_data[f"df2_{col}"] = match_row[col]
            
            combined_data['similarity_score'] = best_score
            
            risultati.append(combined_data)
        else:
            # Se non supera la soglia di similarità, si può comunque salvare la riga di df1 senza match
            # (oppure scartarla del tutto, a seconda dell’obiettivo)
            combined_data = {f"df1_{col}": row[col] for col in df1_clean.columns}
            combined_data['df2_key_clean'] = None
            combined_data['similarity_score'] = best_score
            risultati.append(combined_data)
    
    # Convertiamo la lista di dizionari in DataFrame
    df_risultati = pd.DataFrame(risultati)
    return df_risultati

# Esempio d'uso
# df_merged = fuzzy_merge(df_anagrafica, df_crunchbase, "Ragione sociale", "Organization Name", threshold=80)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 from thefuzz import process, fuzz
#       4 def pulisci_stringa(s: str) -> str:
#       5     """
#       6     Esegue operazioni di cleaning basilari su una stringa:
#       7     - conversione a minuscolo
#       8     - rimozione spazi iniziali/finali
#       9     - (eventualmente) rimozione di punteggiatura o caratteri speciali
#      10     """
#
# ModuleNotFoundError: No module named 'thefuzz'

# %%
df_risultati = fuzzy_merge(df_anagrafica, df_crunchbase, "Ragione sociale", "Organization Name", threshold=90)
df_risultati
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_risultati = fuzzy_merge(df_anagrafica, df_crunchbase, "Ragione sociale", "Organization Name", threshold=90)
#       2 df_risultati
#
# NameError: name 'fuzzy_merge' is not defined

# %%
df_risultati[df_risultati['similarity_score'] >= 90][['df1_Ragione sociale', 'df2_Organization Name', 'similarity_score']].sort_values(by='similarity_score', ascending=True)
# Out:
#                                      df1_Ragione sociale  \
# 7336   MUSIC4MASTERS SOCIETA' A RESPONSABILITA' LIMITATA
# 11820                                         BE.EVO SRL
# 11814  SUPERNOVA INDUSTRIES SOCIETA' A RESPONSABILITA...
# 11806          SNELIX SOCIETA' A RESPONABILITA' LIMITATA
# 11804                              DYMENSION SYSTEMS SRL
# ...                                                  ...
# 4                                        POWER.IT S.R.L.
# 10                                           HINOVIA SRL
# 13                               SHOW REEL AGENCY S.R.L.
# 21                              KIMERA AUTOMOBILI S.R.L.
# 11915                                     ELYSIUM S.R.L.
#
#       df2_Organization Name  similarity_score
# 7336                 Asters                90
# 11820                  Be-E                90
# 11814             Supernova                90
# 11806                Snelix                90
# 11804                   EMS                90
# ...                     ...               ...
# 4                  Power.it               100
# 10                  Hinovia               100
# 13         Show Reel Agency               100
# 21        Kimera Automobili               100
# 11915               Elysium               100
#
# [3287 rows x 3 columns]

# %%
df_risultati = fuzzy_merge(df_anagrafica, df_crunchbase, "Indirizzo sede legale - Codice postale", "Postal Code", threshold=10)
df_risultati
# Out:
#        df1_Unnamed: 0                                df1_Ragione sociale  \
# 0                 1.0                                    RAINSHOW S.R.L.
# 1                 2.0                   CHECKSIG S.R.L. SOCIETA' BENEFIT
# 2                 3.0                                    OTOFARMA S.P.A.
# 3                 4.0                                 SIKELIA OIL S.R.L.
# 4                 5.0                                    POWER.IT S.R.L.
# ...               ...                                                ...
# 11962         11963.0                                    CIFRANDA S.R.L.
# 11963         11964.0                                      SNEARK S.R.L.
# 11964         11965.0                              MATT LAMPEDUSA S.R.L.
# 11965         11966.0  PISTACCHIOBAFFO SOCIETA' A RESPONSABILITA' LIM...
# 11966         11967.0                                 ARREDICURTO S.R.L.
#
#       df1_BvD ID number  df1_Codice fiscale df1_Numero CCIAA  df1_Partita IVA  \
# 0         IT03595550835          3595550835        ME0248323     3.595551e+09
# 1         IT11028330964         11028330964        MI2573724     1.102833e+10
# 2         IT08431301210          8431301210        NA0957454     8.431301e+09
# 3         IT03577640836          3577640836        ME0247028     3.577641e+09
# 4         IT04355290166          4355290166        BG0456683     4.355290e+09
# ...                 ...                 ...              ...              ...
# 11962     IT03106280849          3106280849        AG0227310     3.106281e+09
# 11963     IT03082980842          3082980842        AG0225774     3.082981e+09
# 11964     IT03067220842          3067220842        AG0224714     3.067221e+09
# 11965     IT03033680848          3033680848        AG0222627     3.033681e+09
# 11966     IT03022360840          3022360840        AG0221931     3.022361e+09
#
#           df1_Indirizzo sede legale df1_Provincia  \
# 0           VIA FRANCESCO CRISPI, 4       Messina
# 1                PZA DEL LIBERTY, 8        Milano
# 2         VLE ANTONIO GRAMSCI, 17/B        Napoli
# 3      VIA STRETTO I COCCOMELLI, 64       Messina
# 4           VIA ALESSANDRO NOLI, 13       Bergamo
# ...                             ...           ...
# 11962  VLE CARLO AZEGLIO CIAMPI, 28     Agrigento
# 11963           VIA RE TANCREDI, 20     Agrigento
# 11964        VIA GIOVANNI VERGA, 38     Agrigento
# 11965        VIA MATTEO CIMARRA, 12     Agrigento
# 11966       VLE DELLA VITTORIA, 239     Agrigento
#
#        df1_Indirizzo sede legale - Codice postale  \
# 0                                         98066.0
# 1                                         20121.0
# 2                                         80122.0
# 3                                         98051.0
# 4                                         24125.0
# ...                                           ...
# 11962                                     92026.0
# 11963                                     92100.0
# 11964                                         NaN
# 11965                                     92100.0
# 11966                                     92100.0
#
#       df1_Indirizzo sede legale - Regione  ... df2_Founded Date  \
# 0                                 Sicilia  ...       2019-07-26
# 1                               Lombardia  ...       2023-01-01
# 2                                Campania  ...       2020-11-01
# 3                                 Sicilia  ...       2019-01-01
# 4                               Lombardia  ...       2021-01-01
# ...                                   ...  ...              ...
# 11962                             Sicilia  ...       2021-01-01
# 11963                             Sicilia  ...       2020-06-08
# 11964                             Sicilia  ...       2019-01-01
# 11965                             Sicilia  ...       2020-06-08
# 11966                             Sicilia  ...       2020-06-08
#
#       df2_Founded Date Precision  df2_Operating Status  \
# 0                            day                Active
# 1                           year                Active
# 2                          month                Active
# 3                           year                Active
# 4                           year                Active
# ...                          ...                   ...
# 11962                       year                Active
# 11963                        day                Active
# 11964                        day                Active
# 11965                        day                Active
# 11966                        day                Active
#
#                                          df2_Description  \
# 0      Regensight creates incision-free theranostics ...
# 1                        Fintech, Lending, Payment, SaaS
# 2      2Watch is a media tech company which is into g...
# 3      CodGo provides application development, mobile...
# 4      Service on Demand is an employment agency that...
# ...                                                  ...
# 11962  Wedding In Cloud helps to create a digital alb...
# 11963  Medicud develops a device for treating wounds ...
# 11964  Electrolux Professional is a global provider o...
# 11965  Medicud develops a device for treating wounds ...
# 11966  Medicud develops a device for treating wounds ...
#
#        df2_Estimated Revenue Range df2_Postal Code  \
# 0                      $1M to $10M             198
# 1                              NaN           20121
# 2                      $1M to $10M           80122
# 3                              NaN           98051
# 4                      $1M to $10M           24125
# ...                            ...             ...
# 11962                          NaN            7026
# 11963                          NaN             100
# 11964                  $1B to $10B             NaN
# 11965                          NaN             100
# 11966                          NaN             100
#
#                                 df2_Headquarters Regions  \
# 0      European Union (EU), Europe, Middle East, and ...
# 1      European Union (EU), Europe, Middle East, and ...
# 2      European Union (EU), Europe, Middle East, and ...
# 3      European Union (EU), Europe, Middle East, and ...
# 4      European Union (EU), Europe, Middle East, and ...
# ...                                                  ...
# 11962  European Union (EU), Europe, Middle East, and ...
# 11963  European Union (EU), Europe, Middle East, and ...
# 11964  European Union (EU), Europe, Middle East, and ...
# 11965  European Union (EU), Europe, Middle East, and ...
# 11966  European Union (EU), Europe, Middle East, and ...
#
#       df2_Number of Portfolio Organizations df2_key_clean similarity_score
# 0                                       NaN           198               72
# 1                                       NaN         20121               95
# 2                                       NaN         80122               95
# 3                                       NaN         98051               95
# 4                                       NaN         24125               95
# ...                                     ...           ...              ...
# 11962                                   NaN          7026               73
# 11963                                   NaN           100               90
# 11964                                   NaN           nan              100
# 11965                                   NaN           100               90
# 11966                                   NaN           100               90
#
# [11967 rows x 102 columns]

# %%
df_risultati[df_risultati['similarity_score'] >= 90][['df1_Ragione sociale', 'df2_Organization Name', 'similarity_score']].sort_values(by='similarity_score', ascending=True)
# Out:
#                                      df1_Ragione sociale  \
# 11939                                           NIFA SRL
# 11965  PISTACCHIOBAFFO SOCIETA' A RESPONSABILITA' LIM...
# 11963                                      SNEARK S.R.L.
# 11960                              SNAP-MARKETING S.R.L.
# 11949                                   DIGITALIA S.R.L.
# ...                                                  ...
# 11964                              MATT LAMPEDUSA S.R.L.
# 10140  INNOVA GESTIONI IMMOBILIARI S.R.L. S.B. IN SIG...
# 11023                                 ORIENTALENT S.R.L.
# 11090                               CIRCLE MARKET S.R.L.
# 9954                                    CYBERNOVA S.R.L.
#
#          df2_Organization Name  similarity_score
# 11939                 Yeastime                90
# 11965                  Medicud                90
# 11963                  Medicud                90
# 11960                     NieF                90
# 11949       Annuario Cattolico                90
# ...                        ...               ...
# 11964  Electrolux Professional               100
# 10140  Electrolux Professional               100
# 11023  Electrolux Professional               100
# 11090  Electrolux Professional               100
# 9954   Electrolux Professional               100
#
# [11051 rows x 3 columns]

# %%
df_risultati.columns
# Out:
# Index(['df1_Unnamed: 0', 'df1_Ragione sociale', 'df1_BvD ID number',
#        'df1_Codice fiscale', 'df1_Numero CCIAA', 'df1_Partita IVA',
#        'df1_Indirizzo sede legale', 'df1_Provincia',
#        'df1_Indirizzo sede legale - Codice postale',
#        'df1_Indirizzo sede legale - Regione', 'df1_Sede operativa',
#        'df1_Sede operativa - Provincia', 'df1_Sede operativa - Codice postale',
#        'df1_Sede operativa - Regione - Regione', 'df1_ATECO 2007\ncodice',
#        'df1_Anno di costituzione', 'df1_Fondazione', 'df1_Stato giuridico',
#        'df1_Forma giuridica', 'df1_key_clean', 'df2_key_clean',
#        'similarity_score'],
#       dtype='object')
